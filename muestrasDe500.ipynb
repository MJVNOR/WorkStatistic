# %% [markdown]
# <a href="https://colab.research.google.com/github/MJVNOR/WorkStatistic/blob/master/muestrasDe500.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import statistics as st
from math import log,sqrt,fabs,floor
import matplotlib.pyplot as plt
from numpy.random import seed
import random
from numpy.random import randn
from numpy.random import randint
import math
import seaborn as sns


def media(a):
    return np.mean(a)

#esta es s^2
def varianza_muestral_3(lista):
    sumatoria_elevada = 0
    sumatoria = 0
    for elemento in lista:
        sumatoria_elevada += (elemento)**2
        sumatoria += (elemento)
    n = len(lista)
    dividendo = sumatoria_elevada - (sumatoria**2/n)
    #print("sumaelevada: ",sumatoria_elevada,"suma: ",sumatoria )
    return (dividendo/(n-1))
    
def desviacionMuestral_s(lista):
    sumatoria_elevada = 0
    sumatoria = 0
    for elemento in lista:
        sumatoria_elevada += (elemento)**2
        sumatoria += (elemento)
    n = len(lista)
    dividendo = sumatoria_elevada - (sumatoria**2/n)
    #print("sumaelevada: ",sumatoria_elevada,"suma: ",sumatoria )
    return math.sqrt((dividendo/(n-1)))

# %%
n5 = []
n20 = []
n30 = []
n200 = []

halflife = 1/500

promedio = []
varianza = [] 
desviacion = []
################################################################################

for i in range(500):
    
    for j in range(5):
        n5.append(-(math.log(1-random.random()))/(halflife))
    promedio.append(media(n5))
    varianza.append(varianza_muestral_3(n5))
    desviacion.append(desviacionMuestral_s(n5))
    n5 = []

print("500 muestras de n igual a 5\n")

sns.set()
_ = plt.hist(promedio)
_ = plt.xlabel("Promedio")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(varianza)
_ = plt.xlabel("Varianza")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(desviacion)
_ = plt.xlabel("desviacion")
_ = plt.ylabel("Frecuencia")
plt.show()
# Out:
# 500 muestras de n igual a 5

# %%
################################################################################

for i in range(500):
    
    for j in range(20):
        n20.append(-(math.log(1-random.random()))/(halflife))
    promedio.append(media(n20))
    varianza.append(varianza_muestral_3(n20))
    desviacion.append(desviacionMuestral_s(n20))
    n20 = []

print("500 muestras de n igual a 20\n")

sns.set()
_ = plt.hist(promedio)
_ = plt.xlabel("Promedio")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(varianza)
_ = plt.xlabel("Varianza")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(desviacion)
_ = plt.xlabel("desviacion")
_ = plt.ylabel("Frecuencia")
plt.show()

################################################################################
# Out:
# 500 muestras de n igual a 20

# %%
for i in range(500):
    
    for j in range(20):
        n30.append(-(math.log(1-random.random()))/(halflife))
    promedio.append(media(n30))
    varianza.append(varianza_muestral_3(n30))
    desviacion.append(desviacionMuestral_s(n30))
    n30 = []

print("500 muestras de n igual a 30\n")

sns.set()
_ = plt.hist(promedio)
_ = plt.xlabel("Promedio")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(varianza)
_ = plt.xlabel("Varianza")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(desviacion)
_ = plt.xlabel("desviacion")
_ = plt.ylabel("Frecuencia")
plt.show()

################################################################################
# Out:
# 500 muestras de n igual a 30
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
for i in range(500):
    
    for j in range(20):
        n200.append(-(math.log(1-random.random()))/(halflife))
    promedio.append(media(n200))
    varianza.append(varianza_muestral_3(n200))
    desviacion.append(desviacionMuestral_s(n200))
    n200 = []

print("500 muestras de n igual a 200\n")

sns.set()
_ = plt.hist(promedio)
_ = plt.xlabel("Promedio")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(varianza)
_ = plt.xlabel("Varianza")
_ = plt.ylabel("Frecuencia")
plt.show()

sns.set()
_ = plt.hist(desviacion)
_ = plt.xlabel("desviacion")
_ = plt.ylabel("Frecuencia")
plt.show()

################################################################################
# Out:
# 500 muestras de n igual a 200
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
